# %% [markdown]
# # Fitting Data to Univariate Distribution

# %%
from distfit import distfit
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Generate test data

# %%
data = np.random.normal(loc = 5, scale=10, size=10000)

# %%
# Initialize model
data_m = distfit(bins=25, alpha=0.05, stats='ks')

# %%
# fit to the data
data_m.fit_transform(data, verbose =1 )#Fit best scoring theoretical distribution to the empirical data (X).
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >DEBUG> (np.float64(4.860565894705961), np.float64(9.991529125210631))
# [distfit] >INFO> [norm      ] [0.00 sec] [ks: 1.15279e-07] [loc=4.861 scale=9.992]
# [distfit] >DEBUG> (-31.960603814178718, 36.82116970888468)
# [distfit] >INFO> [expon     ] [0.00 sec] [ks: 1.44841] [loc=-31.961 scale=36.821]
# [distfit] >DEBUG> (np.float64(58321984.082481064), np.float64(-2147483679.9606037), np.float64(2147483647.9999998))
# [distfit] >INFO> [pareto    ] [0.01 sec] [ks: 1.44841] [loc=-2147483679.961 scale=2147483648.000]
# [distfit] >DEBUG> (np.float64(1.2424605128293296), np.float64(5.2613494689542755), np.float64(8.479330589087013))
# [distfit] >INFO> [dweibull  ] [0.09 sec] [ks: 0.00194497] [loc=5.261 scale=8.479]
# [distfit] >DEBUG> (np.float64(127.40640884478266), np.float64(4.861475612587974), np.float64(9.912816907341028))
# [distfit] >INFO> [t         ] [0.62 sec] [ks: 1.15279e-07] [loc=4.861 scale=9.913]
# ...

# %%
data_m.plot(verbose = 1)
# Out:
# [distfit] >INFO> Create pdf plot for the parametric method.
# [distfit] >DEBUG> Loaded backend module://matplotlib_inline.backend_inline version unknown.
# [distfit] >DEBUG> Loaded backend module://matplotlib_inline.backend_inline version unknown.
# [distfit] >DEBUG> findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# [distfit] >DEBUG> findfont: score(FontEntry(fname='c:\\Users\\Hp\\OneDrive\\OLDFILES\\Documents\\PROJECTS\\After Hours\\Probability Distribution\\.venv\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# ...
